# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
df
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   35                   5.0
# 1                   other                1   30                   5.0
# 2                sourcing                1   34                   3.0
# 3                   other                2   39                   1.0
# 4                   other                1   45                   3.0
# ...                   ...              ...  ...                   ...
# 54803            sourcing                1   48                   3.0
# 54804               other                1   37                   2.0
# 54805               other                1   27                   5.0
# 54806            sourcing                1   29                   1.0
# 54807               other                1   27                   1.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                      8              1            0                  49
# 1                      4              0            0                  60
# 2                      7              0            0                  50
# 3                     10              0            0                  50
# 4                      2              0            0                  73
# ...                  ...            ...          ...                 ...
# 54803                 17              0            0                  78
# 54804                  6              0            0                  56
# 54805                  3              1            0                  79
# 54806                  2              0            0                  45
# 54807                  5              0            0                  49
#
#        is_promoted
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 54803            0
# 54804            0
# 54805            0
# 54806            0
# 54807            0
#
# [54808 rows x 14 columns]

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  KPIs_met >80%  awards_won?  avg_training_score  \
# 0                  8              1            0                  49
# 1                  4              0            0                  60
# 2                  7              0            0                  50
# 3                 10              0            0                  50
# 4                  2              0            0                  73
#
#    is_promoted
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
df.columns
# Out:
# Index(['employee_id', 'department', 'region', 'education', 'gender',
#        'recruitment_channel', 'no_of_trainings', 'age', 'previous_year_rating',
#        'length_of_service', 'KPIs_met >80%', 'awards_won?',
#        'avg_training_score', 'is_promoted'],
#       dtype='object')

# %%
df.shape
# Out:
# (54808, 14)

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 6533

# %%
df.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# min             1.000000       0.000000      0.000000           39.000000
# 25%             3.000000       0.000000      0.000000           51.000000
# 50%             5.000000       0.000000      0.000000           60.000000
# 75%             7.000000       1.000000      0.000000           76.000000
# max            37.000000       1.000000      1.000000           99.000000
#
#         is_promoted
# count  54808.000000
# mean       0.085170
# std        0.279137
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54808 entries, 0 to 54807
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           54808 non-null  int64
#  1   department            54808 non-null  object
#  2   region                54808 non-null  object
#  3   education             52399 non-null  object
#  4   gender                54808 non-null  object
#  5   recruitment_channel   54808 non-null  object
#  6   no_of_trainings       54808 non-null  int64
#  7   age                   54808 non-null  int64
#  8   previous_year_rating  50684 non-null  float64
#  9   length_of_service     54808 non-null  int64
#  10  KPIs_met >80%         54808 non-null  int64
#  11  awards_won?           54808 non-null  int64
#  12  avg_training_score    54808 non-null  int64
#  13  is_promoted           54808 non-null  int64
# dtypes: float64(1), int64(8), object(5)
# memory usage: 5.9+ MB

# %%
df.department.unique()
# Out:
# array(['Sales & Marketing', 'Operations', 'Technology', 'Analytics',
#        'R&D', 'Procurement', 'Finance', 'HR', 'Legal'], dtype=object)

# %%
df.region.unique()
# Out:
# array(['region_7', 'region_22', 'region_19', 'region_23', 'region_26',
#        'region_2', 'region_20', 'region_34', 'region_1', 'region_4',
#        'region_29', 'region_31', 'region_15', 'region_14', 'region_11',
#        'region_5', 'region_28', 'region_17', 'region_13', 'region_16',
#        'region_25', 'region_10', 'region_27', 'region_30', 'region_12',
#        'region_21', 'region_8', 'region_32', 'region_6', 'region_33',
#        'region_24', 'region_3', 'region_9', 'region_18'], dtype=object)

# %%
df.region.nunique()
# Out:
# 34

# %%
df.gender.value_counts()
# Out:
# m    38496
# f    16312
# Name: gender, dtype: int64

# %%
df.gender.count()
# Out:
# 54808

# %%
df.recruitment_channel.unique()
# Out:
# array(['sourcing', 'other', 'referred'], dtype=object)

# %%
df.recruitment_channel.nunique()
# Out:
# 3

# %%
df.age.mean()
# Out:
# 34.80391548679025

# %%
df.length_of_service.max()
# Out:
# 37

# %%
df.is_promoted.value_counts()
# Out:
# 0    50140
# 1     4668
# Name: is_promoted, dtype: int64

# %%
df.is_promoted.value_counts(normalize = True)
# Out:
# 0    0.91483
# 1    0.08517
# Name: is_promoted, dtype: float64

# %%
promoted = df[df['is_promoted']==0]
non_promoted = df[df['is_promoted']==1]

# %%
promoted.age.mean()
# Out:
# 34.84403669724771

# %%
non_promoted.age.mean()
# Out:
# 34.372964867180805

# %%
promoted_training_score = df[df['avg_training_score']==0]
non_promoted_training_score = df[df['avg_training_score']==1]

# %%
promoted_training_score.mean()
# Out:
# employee_id             NaN
# department              NaN
# region                  NaN
# education               NaN
# gender                  NaN
# recruitment_channel     NaN
# no_of_trainings         NaN
# age                     NaN
# previous_year_rating    NaN
# length_of_service       NaN
# KPIs_met >80%           NaN
# awards_won?             NaN
# avg_training_score      NaN
# is_promoted             NaN
# dtype: object

# %%
non_promoted_training_score.mean()
# Out:
# employee_id             NaN
# department              NaN
# region                  NaN
# education               NaN
# gender                  NaN
# recruitment_channel     NaN
# no_of_trainings         NaN
# age                     NaN
# previous_year_rating    NaN
# length_of_service       NaN
# KPIs_met >80%           NaN
# awards_won?             NaN
# avg_training_score      NaN
# is_promoted             NaN
# dtype: object

# %%
promoted.avg_training_score.mean()
# Out:
# 62.64768647786199

# %%
non_promoted.avg_training_score.mean()
# Out:
# 71.32519280205655

# %%
promoted.length_of_service.mean()
# Out:
# 5.879397686477862

# %%
promoted['awards_won?'].value_counts(normalize=True,)[1]
# Out:
# 0.01418029517351416

# %%
df['KPIs_met >80%'].corr(df.is_promoted)
# Out:
# 0.22158153967700986

# %%
df['no_of_trainings'].corr(df.is_promoted)
# Out:
# -0.0248959176824125

# %%
df['length_of_service'].corr(df.avg_training_score)
# Out:
# -0.03812215595838484

# %%
df['age'].corr(df.no_of_trainings)
# Out:
# -0.0812778851589133

# %%
df.groupby('department')['age'].mean()
# Out:
# department
# Analytics            32.431241
# Finance              32.058754
# HR                   34.385856
# Legal                33.832531
# Operations           36.073669
# Procurement          35.899972
# R&D                  32.842843
# Sales & Marketing    34.860629
# Technology           34.867190
# Name: age, dtype: float64

# %%
df.groupby('region')['no_of_trainings'].sum()
# Out:
# region
# region_1       712
# region_10      764
# region_11     1561
# region_12      591
# region_13     3121
# region_14      937
# region_15     3454
# region_16     1739
# region_17      899
# region_18       33
# region_19     1041
# region_2     16080
# region_20     1017
# region_21      501
# region_22     9036
# region_23     1456
# region_24      624
# region_25     1004
# region_26     2696
# region_27     2093
# region_28     1665
# region_29     1167
# region_3       390
# region_30      761
# region_31     2443
# region_32     1161
# region_33      300
# region_34      351
# region_4      2017
# region_5       910
# region_6       803
# region_7      6116
# region_8       703
# region_9       529
# Name: no_of_trainings, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

for column in df.select_dtypes(include='object').columns:
    df[column] = label_encoder.fit_transform(df[column])

corr = df.corr()

# %%
corr
# Out:
#                       employee_id  department    region  education    gender  \
# employee_id              1.000000   -0.005187 -0.003423   0.003332 -0.001542
# department              -0.005187    1.000000 -0.020592   0.068075 -0.030108
# region                  -0.003423   -0.020592  1.000000  -0.006510  0.019730
# education                0.003332    0.068075 -0.006510   1.000000  0.010125
# gender                  -0.001542   -0.030108  0.019730   0.010125  1.000000
# recruitment_channel      0.005960    0.004732 -0.000920  -0.005973  0.006567
# no_of_trainings         -0.005121    0.014152 -0.004590  -0.044336  0.084501
# age                      0.000437    0.079162 -0.088918   0.233830 -0.016293
# previous_year_rating     0.004533   -0.143596 -0.005002  -0.002265 -0.024232
# length_of_service        0.001274    0.059060 -0.058939   0.161002 -0.019675
# KPIs_met >80%           -0.002501   -0.088209 -0.007664  -0.018008 -0.037400
# awards_won?              0.008420   -0.002151  0.000307  -0.001175  0.002381
# avg_training_score      -0.000586   -0.251626  0.023572  -0.022174 -0.024494
# is_promoted              0.001206    0.000130  0.008841   0.009608 -0.011109
#
#                       recruitment_channel  no_of_trainings       age  \
# employee_id                      0.005960        -0.005121  0.000437
# department                       0.004732         0.014152  0.079162
# region                          -0.000920        -0.004590 -0.088918
# education                       -0.005973        -0.044336  0.233830
# gender                           0.006567         0.084501 -0.016293
# recruitment_channel              1.000000        -0.010405 -0.011400
# no_of_trainings                 -0.010405         1.000000 -0.081278
# age                             -0.011400        -0.081278  1.000000
# previous_year_rating             0.006135        -0.063126  0.006008
# length_of_service               -0.002887        -0.057275  0.657111
# KPIs_met >80%                   -0.000297        -0.045576 -0.025592
# awards_won?                     -0.005510        -0.007628 -0.008169
# avg_training_score              -0.002416         0.042517 -0.048380
# is_promoted                      0.002229        -0.024896 -0.017166
#
#                       previous_year_rating  length_of_service  KPIs_met >80%  \
# employee_id                       0.004533           0.001274      -0.002501
# department                       -0.143596           0.059060      -0.088209
# region                           -0.005002          -0.058939      -0.007664
# education                        -0.002265           0.161002      -0.018008
# gender                           -0.024232          -0.019675      -0.037400
# recruitment_channel               0.006135          -0.002887      -0.000297
# no_of_trainings                  -0.063126          -0.057275      -0.045576
# age                               0.006008           0.657111      -0.025592
# previous_year_rating              1.000000           0.000253       0.351578
# length_of_service                 0.000253           1.000000      -0.077693
# KPIs_met >80%                     0.351578          -0.077693       1.000000
# awards_won?                       0.027738          -0.039927       0.097000
# avg_training_score                0.075139          -0.038122       0.078391
# is_promoted                       0.159320          -0.010670       0.221582
#
#                       awards_won?  avg_training_score  is_promoted
# employee_id              0.008420           -0.000586     0.001206
# department              -0.002151           -0.251626     0.000130
# region                   0.000307            0.023572     0.008841
# education               -0.001175           -0.022174     0.009608
# gender                   0.002381           -0.024494    -0.011109
# recruitment_channel     -0.005510           -0.002416     0.002229
# no_of_trainings         -0.007628            0.042517    -0.024896
# age                     -0.008169           -0.048380    -0.017166
# previous_year_rating     0.027738            0.075139     0.159320
# length_of_service       -0.039927           -0.038122    -0.010670
# KPIs_met >80%            0.097000            0.078391     0.221582
# awards_won?              1.000000            0.072138     0.195871
# avg_training_score       0.072138            1.000000     0.181147
# is_promoted              0.195871            0.181147     1.000000

# %%
sns.heatmap(corr,annot=True, fmt='.1f')
plt.figure(figsize=(4,5))
plt.show()

# %%
sns.barplot(x='department', y='employee_id', data = df, errorbar=None,estimator='count')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.barplot(x='region', y='is_promoted', data = df, errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='is_promoted', y='avg_training_score', data = df, errorbar=None)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.relplot(x='department',hue='is_promoted', y='age', data=df, kind='line', errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x='is_promoted', y='age', data=df,errorbar=None)
# Out:
# <Axes: xlabel='is_promoted', ylabel='age'>

# %%
sns.barplot(x='is_promoted',y='length_of_service', data=df)
# Out:
# <Axes: xlabel='is_promoted', ylabel='length_of_service'>

# %%
sns.barplot(x='is_promoted', y='KPIs_met >80%', data=df)
# Out:
# <Axes: xlabel='is_promoted', ylabel='KPIs_met >80%'>

# %%
awared=df['awards_won?'].value_counts()
label = ['No', 'Won']

# %%
label
# Out:
# ['No', 'Won']

# %%
plt.pie(awared, labels=label, autopct='%.0f%%')
plt.show()

# %%
sns.barplot(x='is_promoted', y='previous_year_rating', data=df, errorbar=None)
# Out:
# <Axes: xlabel='is_promoted', ylabel='previous_year_rating'>

# %%
sns.barplot(x='no_of_trainings', y='employee_id', data=df, errorbar=None, estimator='count')
# Out:
# <Axes: xlabel='no_of_trainings', ylabel='employee_id'>

# %%
training= df.groupby('no_of_trainings')['employee_id'].count()
training
# Out:
# no_of_trainings
# 1     44378
# 2      7987
# 3      1776
# 4       468
# 5       128
# 6        44
# 7        12
# 8         5
# 9         5
# 10        5
# Name: employee_id, dtype: int64

# %%
sns.displot(df, x="department", hue="gender", multiple="dodge")
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#    employee_id  department  region  education  gender  recruitment_channel  \
# 0        65438           7      31          2       0                    2
# 1        65141           4      14          0       1                    0
# 2         7513           7      10          0       1                    2
# 3         2542           7      15          0       1                    0
# 4        48945           8      18          0       1                    0
#
#    no_of_trainings  age  previous_year_rating  length_of_service  \
# 0                1   35                   5.0                  8
# 1                1   30                   5.0                  4
# 2                1   34                   3.0                  7
# 3                2   39                   1.0                 10
# 4                1   45                   3.0                  2
#
#    KPIs_met >80%  awards_won?  avg_training_score  is_promoted
# 0              1            0                  49            0
# 1              0            0                  60            0
# 2              0            0                  50            0
# 3              0            0                  50            0
# 4              0            0                  73            0

# %%
sns.barplot(hue='recruitment_channel', y='employee_id', data=df, errorbar=None, estimator='count', x='department')
plt.xticks(rotation=90)
plt.show()

# %%
df.recruitment_channel.value_counts(ascending=False)
# Out:
# 0    30446
# 2    23220
# 1     1142
# Name: recruitment_channel, dtype: int64

# %%
sns.barplot(y='is_promoted', x='education', data=df)
# Out:
# <Axes: xlabel='education', ylabel='is_promoted'>

# %%
sns.relplot(y='is_promoted', x='education', data=df, kind='line',errorbar=None)

# %%
sns.barplot(x='recruitment_channel', y='age', data=df, errorbar=None)
# Out:
# <Axes: xlabel='recruitment_channel', ylabel='age'>

# %%
round(df.groupby('department')['age'].mean(),0)
# Out:
# department
# 0    32.0
# 1    32.0
# 2    34.0
# 3    34.0
# 4    36.0
# 5    36.0
# 6    33.0
# 7    35.0
# 8    35.0
# Name: age, dtype: float64

# %%
sns.barplot(x='department', y='age', estimator='mean', data=df, errorbar=None)
plt.xticks(rotation=90)
plt.show()

# %%
sns.boxplot(y='length_of_service', data=df)
# Out:
# <Axes: ylabel='length_of_service'>

# %%
df.length_of_service.value_counts(ascending=False)
# Out:
# 3     7033
# 4     6836
# 2     6684
# 5     5832
# 7     5551
# 6     4734
# 1     4547
# 8     2883
# 9     2629
# 10    2193
# 11     916
# 12     794
# 13     687
# 15     593
# 14     549
# 16     548
# 17     432
# 18     392
# 19     329
# 20     128
# 21      78
# 24      70
# 23      65
# 22      61
# 25      51
# 26      41
# 27      36
# 28      30
# 29      30
# 31      20
# 30      12
# 32      10
# 33       9
# 34       4
# 37       1
# Name: length_of_service, dtype: int64

# %%
sns.countplot(x='no_of_trainings',hue='is_promoted', data=df)
# Out:
# <Axes: xlabel='no_of_trainings', ylabel='count'>

# %%
sns.countplot(x='is_promoted',hue='gender', data=df)
# Out:
# <Axes: xlabel='is_promoted', ylabel='count'>

# %%
df.groupby('is_promoted')['gender'].value_counts()
# Out:
# is_promoted  gender
# 0            1         35295
#              0         14845
# 1            1          3201
#              0          1467
# Name: gender, dtype: int64

# %%
dep = df.department.value_counts()
dep
# Out:
# 7    16840
# 4    11348
# 8     7138
# 5     7138
# 0     5352
# 1     2536
# 2     2418
# 3     1039
# 6      999
# Name: department, dtype: int64

# %%
pro = df.groupby('department')['is_promoted'].count()
pro
# Out:
# department
# 0     5352
# 1     2536
# 2     2418
# 3     1039
# 4    11348
# 5     7138
# 6      999
# 7    16840
# 8     7138
# Name: is_promoted, dtype: int64

# %%
fig, ax = plt.subplots(3,3)
ax = ax.flatten()
tab = pd.crosstab(df['department'],df['is_promoted'])
for i,x in enumerate(tab.index):
    tab.loc[x].plot.pie(ax=ax[i],startangle=90)

# %%
plt.pie(dep,labels=dep.index, autopct='%.0f%%')
plt.show()

# %%
plt.figure(figsize=(12,5))
sns.barplot(df, x="age", y="is_promoted", errorbar=None)
plt.xticks(rotation=90)
plt.show()
